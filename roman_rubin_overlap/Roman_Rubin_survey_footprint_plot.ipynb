# %% [markdown]
# # Survey Footprint Illustration
#
# The purpose of this notebook is to create a graphic illustrating the proposed footprint of the Roman Galactic Bulge Time Domain Survey.

# %%
from astropy.coordinates import SkyCoord
from astropy import units as u
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
import numpy as np

# %%
roman_survey_center = SkyCoord('18:03:04', '-28:36:39', frame='icrs', unit=(u.hourangle, u.deg))
roman_survey_center
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (270.76666667, -28.61083333)>

# %% [markdown]
# Roman's survey footprint can be generated using the tool from STScI: http://gsss.stsci.edu/webservices/footprints/webform.aspx

# %%
class RomanFootprint():

    def __init__(self):
        self.set_wfi_footprint()
        self.set_bulge_center_footprint()
        
    def set_wfi_footprint(self):
        self.wfi_footprint = [
            [(-0.01553379, -0.00317668),
             (-0.07816706, 0.10730291),
             (0.03044324, 0.17116874), 
             (0.09357766, 0.05982127), 
             (-0.01553379, -0.00317668)],
            [(-0.13243418, -0.07067170),
             (-0.19543161, 0.03843946), 
             (-0.08905830, 0.10216900),
             (-0.02592517, -0.00917639),
             (-0.13243418, -0.07067170)],
            [(-0.25798728, -0.14316200),
             (-0.32234801, -0.03368796), 
             (-0.21757883, 0.02680620),
             (-0.15408184, -0.08317043), 
             (-0.25798728, -0.14316200)],
            [(-0.05545692, 0.13196252),
             (-0.11722447, 0.24294125),
             (-0.00861444, 0.30680938), 
             (0.05452034, 0.19546292), 
             (-0.05545692, 0.13196252)],
            [(-0.17235678, 0.06446419),
             (-0.23412250, 0.17544056),
             (-0.12724969, 0.23830712),
             (-0.06548224, 0.12732855),
             (-0.17235678, 0.06446419)],
            [(-0.29927477, -0.00766454),
             (-0.36003795, 0.10157699),
             (-0.25626947, 0.16380670),
             (-0.19500419, 0.05369667),
             (-0.29927477, -0.00766454)],
            [(-0.06853602, 0.28260188),
             (-0.13030407, 0.39357869),
             (-0.02082738, 0.45794876),
             (0.04094212, 0.34697051),
             (-0.06853602, 0.28260188)],
            [(-0.18507068, 0.21646614),
             (-0.24547103, 0.32707504),
             (-0.13909750, 0.39081027),
             (-0.07732951, 0.27983367),
             (-0.18507068, 0.21646614)],
            [(-0.31285525, 0.14383266),
             (-0.37275310, 0.25357293),
             (-0.26898406, 0.31580637),
             (-0.20821830, 0.20656389), 
             (-0.31285525, 0.14383266)],
            [(0.05383136, -0.12131616),
             (-0.01053385, -0.01183650),
             (0.09857768, 0.05116129), 
             (0.16344378, -0.05918633), 
             (0.05383136, -0.12131616)],
            [(-0.06393661, -0.18930837),
             (-0.12743436, -0.07933132),
             (-0.02092524, -0.01783620),
             (0.04393987, -0.12818163), 
             (-0.06393661, -0.18930837)],
            [(-0.18999197, -0.26092919), 
             (-0.25385351, -0.15232131),
             (-0.14908205, -0.09182999),
             (-0.08558457, -0.20180649),
             (-0.18999197, -0.26092919)],
            [(0.15177330, -0.22295616),
             (0.08654208, -0.11397727), 
             (0.19652137, -0.05048101),
             (0.26188717, -0.16169371),
             (0.15177330, -0.22295616)],
            [(0.03486903, -0.29044661),
             (-0.03036111, -0.18147024),
             (0.07751650, -0.12034281),
             (0.14324767, -0.23018743),
             (0.03486903, -0.29044661)],
            [(-0.09205566, -0.36256522),
             (270.97207225, -28.67673140),
             (270.99291512, -28.80241934), 
             (270.84902532, -28.81764965)],
            [(270.69505115, -28.83485171), 
             (270.68035550, -28.70948654), 
             (270.82072556, -28.69481398), 
             (270.83686331, -28.82103112),
             (270.69505115, -28.83485171)],
            [(270.53197209, -28.85287427), 
             (270.51082184, -28.72923343), 
             (270.64911600, -28.71597967), 
             (270.66929400, -28.83972750), 
             (270.53197209, -28.85287427)]
        ]
    
    def offset_footprint(self, dra, ddec):
        footprint = []
        for outline in self.bulge_center_roll22:
            fov = []
            for coords in outline:
                fov.append([coords[0]+dra, coords[1]+ddec])
            footprint.append(fov)
        return footprint
    
    def set_bulge_survey_footprint(self):
        field_offsets = [(0.0,0.0), (0.3,0.0),(0.6,0.0),(0.9,0.0),(1.2,0.0),(1.5,0.0),
                         (0.0,0.6), (0.3, 0.6)]
        field_offsets = [(0.0,0.0), (0.5,0.05), (1.0, 0.1), (1.5, 0.15), (2.0, 0.2),
                         (-0.1, 0.82), (0.4, 0.88)]
        self.bulge_survey_footprint = []
        for offsets in field_offsets:
            footprint = self.offset_footprint(offsets[0],offsets[1])
            self.bulge_survey_footprint.append(footprint)

# %%
roman_footprint = RomanFootprint()
roman_footprint.set_bulge_survey_footprint()

# %%
(fig, ax) = plt.subplots(1, 1, figsize=(10, 10))

xmin = 1e4
xmax = -1e4
ymin = 1e4
ymax = -1e4
for outline in roman_footprint.bulge_center_roll45:
    fov = np.array(outline)
    p = Polygon(fov, facecolor='white', edgecolor='black')
    ax.add_patch(p)
    xmin = min(xmin, fov[:,0].min())
    xmax = max(xmax, fov[:,0].max())
    ymin = min(ymin, fov[:,1].min())
    ymax = max(ymax, fov[:,1].max())

for outline in roman_footprint.bulge_center:
    fov = np.array(outline)
    p = Polygon(fov, facecolor='white', edgecolor='red')
    ax.add_patch(p)
    xmin = min(xmin, fov[:,0].min())
    xmax = max(xmax, fov[:,0].max())
    ymin = min(ymin, fov[:,1].min())
    ymax = max(ymax, fov[:,1].max())
    
for outline in roman_footprint.bulge_center_roll22:
    fov = np.array(outline)
    p = Polygon(fov, facecolor='white', edgecolor='blue')
    ax.add_patch(p)
    xmin = min(xmin, fov[:,0].min())
    xmax = max(xmax, fov[:,0].max())
    ymin = min(ymin, fov[:,1].min())
    ymax = max(ymax, fov[:,1].max())
    
ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
plt.show()

# %%
(fig, ax) = plt.subplots(1, 1, figsize=(10, 10))

xmin = 1e4
xmax = -1e4
ymin = 1e4
ymax = -1e4
for field in roman_footprint.bulge_survey_footprint:
    for outline in field:
        fov = np.array(outline)
        p = Polygon(fov, facecolor='white', edgecolor='black')
        ax.add_patch(p)
        xmin = min(xmin, fov[:,0].min())
        xmax = max(xmax, fov[:,0].max())
        ymin = min(ymin, fov[:,1].min())
        ymax = max(ymax, fov[:,1].max())

ax.set_xlim([xmin, xmax])
ax.set_ylim([ymin, ymax])
plt.show()

# %% [markdown]
# Extinction map in the background taken from Gonzalez et al 2012: https://www.researchgate.net/publication/224285377_Reddening_and_metallicity_maps_of_the_Milky_Way_bulge_from_VVV_and_2MASSII_The_complete_high_resolution_extinction_map_and_implications_for_Bulgestudies
